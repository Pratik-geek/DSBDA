# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv('dataset_Facebook.csv', sep=';')
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
pd.get_option("display.max_columns")
pd.set_option("display.max_columns", None)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photo = data[data['Type'] == 'Photo']
video = data[data['Type'] == 'Video']
status = data[data['Type'] == 'Status']
link = data[data['Type'] == 'Link']

# %%
photo
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
video.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
link.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
merged = pd.concat([video,link], ignore_index = True)

# %%
merged
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             138895  Video         1          12             4         11
# 1             138329  Video         1          11             6          2
# 2             137893  Video         1          11             5          3
# 3             137893  Video         1          11             3         11
# 4             134879  Video         1           9             2         10
# 5             130791  Video         1           7             3         11
# 6             126424  Video         1           6             2         13
# 7             138414   Link         1          12             7         10
# 8             138895   Link         1          12             6          3
# 9             138353   Link         1          12             5          3
# 10            138353   Link         1          12             4          3
# ...

# %%
merged.size
# Out:
# 551

# %%
sorted_data = data.sort_values('Page total likes')

# %%
sorted_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
transpose_data = data.transpose()

# %%
transpose_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
melted_data = pd.melt(data, id_vars=['Type'], value_vars=['Lifetime Engaged Users', 'Lifetime Post Consumers'])

# %%
melted_data
# Out:
#        Type                 variable  value
# 0     Photo   Lifetime Engaged Users    178
# 1    Status   Lifetime Engaged Users   1457
# 2     Photo   Lifetime Engaged Users    177
# 3     Photo   Lifetime Engaged Users   2211
# 4     Photo   Lifetime Engaged Users    671
# ..      ...                      ...    ...
# 995   Photo  Lifetime Post Consumers    708
# 996   Photo  Lifetime Post Consumers    508
# 997   Photo  Lifetime Post Consumers    572
# 998   Photo  Lifetime Post Consumers    574
# 999   Photo  Lifetime Post Consumers    524
#
# [1000 rows x 3 columns]

# %%
wide_data = pd.pivot_table(data, index='Type', columns='Post Month', values='Lifetime Post Total Reach', aggfunc='sum')

# %%
wide_data
# Out:
# Post Month        1         2         3         4         5         6   \
# Type
# Link         95626.0    9356.0   15539.0  140464.0   12540.0       NaN
# Photo       213272.0  605370.0  450078.0  774384.0  339412.0  660109.0
# Status           NaN       NaN    9120.0   17912.0   43216.0   20672.0
# Video            NaN       NaN       NaN       NaN       NaN  139008.0
#
# Post Month        7         8         9         10        11        12
# Type
# Link             NaN       NaN       NaN   77272.0   21176.0   36008.0
# Photo       897242.0  358705.0  197273.0  399025.0  438033.0  263806.0
# Status       98520.0   52088.0   54692.0  115588.0   24476.0  152266.0
# Video        21872.0       NaN   30624.0       NaN  130728.0   36208.0
