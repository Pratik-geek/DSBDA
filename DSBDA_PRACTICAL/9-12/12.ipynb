# %%
import pandas as pd
column_names = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','country','income']
df = pd.read_csv('adult.csv', names = column_names)
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
male = df[df['sex']==' Male']
male
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32557   40            Private  154374        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
cuba = df[df['country']==' Cuba']
cuba
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 4       28            Private  338409   Bachelors             13
# 81      52            Private  276515   Bachelors             13
# 638     47       Self-emp-inc  248145     5th-6th              3
# 701     31            Private  243605   Bachelors             13
# 1237    41   Self-emp-not-inc  209344     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 30841   37            Private  238433     1st-4th              2
# 30892   52            Private  222646        12th              8
# 30906   39   Self-emp-not-inc  251323         9th              5
# 31149   52       Self-emp-inc  230767   Bachelors             13
# 31907   48            Private  379883     Masters             14
#
#             marital-status          occupation     relationship    race  \
# 4       Married-civ-spouse      Prof-specialty             Wife   Black
# ...

# %%
merge = pd.concat([cuba,male],ignore_index=True)
merge
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       28            Private  338409      Bachelors             13
# 1       52            Private  276515      Bachelors             13
# 2       47       Self-emp-inc  248145        5th-6th              3
# 3       31            Private  243605      Bachelors             13
# 4       41   Self-emp-not-inc  209344        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 21880   32            Private  116138        Masters             14
# 21881   53            Private  321865        Masters             14
# 21882   22            Private  310152   Some-college             10
# 21883   40            Private  154374        HS-grad              9
# 21884   22            Private  201490        HS-grad              9
#
#             marital-status          occupation     relationship  \
# 0       Married-civ-spouse      Prof-specialty             Wife
# ...

# %%
female = df[df['sex']==' Female']
female
merge1 = pd.concat([male,female],ignore_index=True)
merge1
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32556   37            Private  198216     Assoc-acdm             12
# 32557   43          State-gov  255835   Some-college             10
# 32558   27            Private  257302     Assoc-acdm             12
# 32559   58            Private  151910        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
new = df.sort_values('capital-gain')
new
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 16280   27        Private  187981        HS-grad              9
# 19989   42        Private   68729   Some-college             10
# 19988   38   Self-emp-inc  299036      Bachelors             13
# 19987   45      State-gov  187581      Assoc-voc             11
# 19986   19              ?  385901   Some-college             10
# ...    ...            ...     ...            ...            ...
# 15100   62   Self-emp-inc  245491      Bachelors             13
# 10661   59        Private  122283    Prof-school             15
# 2103    43   Self-emp-inc  172826   Some-college             10
# 25178   45        Private  148995      Doctorate             16
# 6524    49   Self-emp-inc  362795        Masters             14
#
#             marital-status          occupation    relationship  \
# 16280        Never-married   Handlers-cleaners       Own-child
# 19989        Never-married        Craft-repair   Not-in-family
# ...

# %%
transp = df.transpose()
transp
# Out:
#                          0                    1                   2      \
# age                         39                   50                  38
# workclass            State-gov     Self-emp-not-inc             Private
# fnlwgt                   77516                83311              215646
# education            Bachelors            Bachelors             HS-grad
# education-num               13                   13                   9
# marital-status   Never-married   Married-civ-spouse            Divorced
# occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# relationship     Not-in-family              Husband       Not-in-family
# race                     White                White               White
# sex                       Male                 Male                Male
# capital-gain              2174                    0                   0
# capital-loss                 0                    0                   0
# ...

# %%
melt = pd.melt(df,id_vars=['age'],value_vars=['capital-gain','capital-loss'],var_name='feature',value_name='values')
melt
# Out:
#        age       feature  values
# 0       39  capital-gain    2174
# 1       50  capital-gain       0
# 2       38  capital-gain       0
# 3       53  capital-gain       0
# 4       28  capital-gain       0
# ...    ...           ...     ...
# 65117   27  capital-loss       0
# 65118   40  capital-loss       0
# 65119   58  capital-loss       0
# 65120   22  capital-loss       0
# 65121   52  capital-loss       0
#
# [65122 rows x 3 columns]

# %%
cast = pd.pivot_table(melt,index='age',columns='feature',values='values',aggfunc='sum')
cast
# Out:
# feature  capital-gain  capital-loss
# age
# 17              43328         16492
# 18              56132         24385
# 19              65570         31268
# 20              62338         25074
# 21             147330         37178
# ..                ...           ...
# 85                  0             0
# 86                  0             0
# 87                  0             0
# 88                  0             0
# 90              83216          6562
#
# [73 rows x 2 columns]
