# %%
import pandas as pd
# column_names = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','country','salary']
cl = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df = pd.read_csv('Switzerland.csv', names=cl)
df
# Out:
#      age  sex  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0     32    1   1       95     0   ?       0     127     0      .7     1  ?
# 1     34    1   4      115     0   ?       ?     154     0      .2     1  ?
# 2     35    1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3     36    1   4      110     0   ?       0     125     1       1     2  ?
# 4     38    0   4      105     0   ?       0     166     0     2.8     1  ?
# ..   ...  ...  ..      ...   ...  ..     ...     ...   ...     ...   ... ..
# 118   70    1   4      115     0   0       1      92     1       0     2  ?
# 119   70    1   4      140     0   1       0     157     1       2     2  ?
# 120   72    1   3      160     0   ?       2     114     0     1.6     2  2
# 121   73    0   3      160     0   0       1     121     0       0     1  ?
# 122   74    1   2      145     0   ?       1     123     0     1.3     1  ?
#
#     thal  num
# 0      ?    1
# 1      ?    1
# ...

# %%
df.shape
# Out:
# (123, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.replace('?',pd.NA,inplace=True)

# %%
df
# Out:
#      age  sex  cp trestbps  chol   fbs restecg thalach exang oldpeak slope  \
# 0     32    1   1       95     0   NaN       0     127     0      .7     1
# 1     34    1   4      115     0   NaN    <NA>     154     0      .2     1
# 2     35    1   4     <NA>     0   NaN       0     130     1    <NA>  <NA>
# 3     36    1   4      110     0   NaN       0     125     1       1     2
# 4     38    0   4      105     0   NaN       0     166     0     2.8     1
# ..   ...  ...  ..      ...   ...   ...     ...     ...   ...     ...   ...
# 118   70    1   4      115     0     0       1      92     1       0     2
# 119   70    1   4      140     0     1       0     157     1       2     2
# 120   72    1   3      160     0  <NA>       2     114     0     1.6     2
# 121   73    0   3      160     0     0       1     121     0       0     1
# 122   74    1   2      145     0  <NA>       1     123     0     1.3     1
#
#        ca  thal  num
# 0     NaN  <NA>    1
# 1     NaN  <NA>    1
# ...

# %%
df= df.apply(pd.to_numeric,errors='coerce')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     32    1   1      95.0     0  NaN      0.0    127.0    0.0      0.7
# 1     34    1   4     115.0     0  NaN      NaN    154.0    0.0      0.2
# 2     35    1   4       NaN     0  NaN      0.0    130.0    1.0      NaN
# 3     36    1   4     110.0     0  NaN      0.0    125.0    1.0      1.0
# 4     38    0   4     105.0     0  NaN      0.0    166.0    0.0      2.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 118   70    1   4     115.0     0  0.0      1.0     92.0    1.0      0.0
# 119   70    1   4     140.0     0  1.0      0.0    157.0    1.0      2.0
# 120   72    1   3     160.0     0  NaN      2.0    114.0    0.0      1.6
# 121   73    0   3     160.0     0  0.0      1.0    121.0    0.0      0.0
# 122   74    1   2     145.0     0  NaN      1.0    123.0    0.0      1.3
#
#      slope   ca  thal  num
# 0      1.0  NaN   NaN    1
# 1      1.0  NaN   NaN    1
# ...

# %%
from scipy.stats import zscore

# Calculate Z-scores for each column
z_scores = df.apply(zscore)

# Set threshold for Z-score
threshold = 1

# Remove rows with outliers
data_no_outliers = df[(z_scores < threshold).all(axis=1)]

# %%
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num]
# Index: []
