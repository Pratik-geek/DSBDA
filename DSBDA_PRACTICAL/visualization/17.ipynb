# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
cl = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df = pd.read_csv('Cleavland.csv', names=cl)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#Histogram
plt.hist(df['age'],bins=15)
plt.xlabel('AGE')
plt.ylabel('FREQUENCY')
plt.title('HISTOGRAM')
plt.show()

# %%
plt.plot(df['sex'],df['age'],'go',alpha=0.5)
plt.xlabel('sex')
plt.ylabel('age')
plt.title('DOT PLOT')
plt.show()

# %%
gc = df['sex'].value_counts()
gc
plt.bar(gc.index,gc.values)
plt.xlabel('Gender')
plt.ylabel('counts')
plt.title('BAR PLOTS')
plt.show()

# %%
#LINECHART
plt.plot(df['age'],df['trestbps'],'g')
plt.xlabel('AGE')
plt.ylabel('trestbps')
plt.title('LINE CHART')
plt.show()

# %%
plt.scatter(df['age'],df['trestbps'])
plt.xlabel('AGE')
plt.ylabel('trestbps')
plt.title('LINE CHART')
plt.show()

# %%
gc = df['sex'].value_counts()
gc
# Out:
# 1.0    206
# 0.0     97
# Name: sex, dtype: int64

# %%
plt.pie(gc,labels=gc.index)
plt.title('PIE CHART')
plt.show()

# %%
#BOX PLOT
plt.boxplot(df['chol'])
plt.xlabel('cholestrol')
plt.title('Box Plot: Cholesterol')
plt.show()
